# %%
#Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load Main Datasets
df = pd.read_csv('Lego_dataset_cleaned.csv')

# %%
df
# Out:
#        piece_count  list_price  num_reviews  play_star_rating  star_rating  \
# 0        -0.273020     29.9900    -0.398512         -0.655279    -0.045687
# 1        -0.404154     19.9900    -0.398512         -0.655279     0.990651
# 2        -0.517242     12.9900    -0.147162         -0.132473    -0.460222
# 3         0.635296     99.9900     0.187972         -1.352353     0.161581
# 4         0.288812     79.9900    -0.063378         -2.049427     0.161581
# ...            ...         ...          ...               ...          ...
# 10865    -0.300690     42.6878     0.048333         -0.306741    -0.667489
# 10866    -0.360843     30.4878    -0.230945         -0.481010    -0.252954
# 10867    -0.364453     30.4878     0.076261         -0.481010     0.161581
# 10868    -0.436637     18.2878    -0.258873         -0.655279    -0.874757
# 10869    -0.457089     18.2878     0.048333          0.216064     0.368848
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Columns: 103 entries, piece_count to review_difficulty_unknown
# dtypes: float64(6), int64(97)
# memory usage: 8.5 MB

# %%
df.shape
# Out:
# (10870, 103)

# %%
df.head()
# Out:
#    piece_count  list_price  num_reviews  play_star_rating  star_rating  \
# 0    -0.273020       29.99    -0.398512         -0.655279    -0.045687
# 1    -0.404154       19.99    -0.398512         -0.655279     0.990651
# 2    -0.517242       12.99    -0.147162         -0.132473    -0.460222
# 3     0.635296       99.99     0.187972         -1.352353     0.161581
# 4     0.288812       79.99    -0.063378         -2.049427     0.161581
#
#    val_star_rating  ages_10+  ages_10-14  ages_10-16  ages_10-21  ...  \
# 0        -0.365010         0           0           0           0  ...
# 1        -0.365010         0           0           0           0  ...
# 2        -0.204063         0           0           0           0  ...
# 3         0.117830         0           0           0           0  ...
# 4        -0.204063         0           0           0           0  ...
#
#    country_NZ  country_PL  country_PT  country_US  review_difficulty_Average  \
# ...

# %%
df.dtypes
# Out:
# piece_count                           float64
# list_price                            float64
# num_reviews                           float64
# play_star_rating                      float64
# star_rating                           float64
#                                        ...
# review_difficulty_Challenging           int64
# review_difficulty_Easy                  int64
# review_difficulty_Very Challenging      int64
# review_difficulty_Very Easy             int64
# review_difficulty_unknown               int64
# Length: 103, dtype: object

# %%
df.tail()
# Out:
#        piece_count  list_price  num_reviews  play_star_rating  star_rating  \
# 10865    -0.300690     42.6878     0.048333         -0.306741    -0.667489
# 10866    -0.360843     30.4878    -0.230945         -0.481010    -0.252954
# 10867    -0.364453     30.4878     0.076261         -0.481010     0.161581
# 10868    -0.436637     18.2878    -0.258873         -0.655279    -0.874757
# 10869    -0.457089     18.2878     0.048333          0.216064     0.368848
#
#        val_star_rating  ages_10+  ages_10-14  ages_10-16  ages_10-21  ...  \
# 10865         0.278777         0           0           0           0  ...
# 10866        -0.204063         0           0           0           0  ...
# 10867         0.278777         0           0           0           0  ...
# 10868         0.278777         0           0           0           0  ...
# 10869         0.600671         0           0           0           0  ...
#
#        country_NZ  country_PL  country_PT  country_US  \
# ...

# %%
#Load Train Dataset
train = pd.read_csv('lego_train.csv')

# %%
train
# Out:
#      prod_id                       set_name  \
# 0      60123      Volcano Supply Helicopter
# 1      71246      Adventure Time™ Team Pack
# 2      10616             My First Playhouse
# 3      31079            Sunshine Surfer Van
# 4      42057          Ultralight Helicopter
# ..       ...                            ...
# 553    71343  The Powerpuff Girls™ Fun Pack
# 554    75114      First Order Stormtrooper™
# 555    41597                    Go Brick Me
# 556    75116                           Finn
# 557    76097      Lex Luthor™ Mech Takedown
#
#                                              prod_desc  \
# 0    Fly in the exploration gear and fly out the cr...
# 1    Explore the Land of Ooo with Jake and Lumpy Sp...
# 2    Learn about daily routines with this easy-to-b...
# 3    Enjoy seaside fun with the 3-in-1 Sunshine Sur...
# 4    Take to the skies with the Ultralight Helicopter!
# ..                                                 ...
# ...

# %%
train.head()
# Out:
#    prod_id                   set_name  \
# 0    60123  Volcano Supply Helicopter
# 1    71246  Adventure Time™ Team Pack
# 2    10616         My First Playhouse
# 3    31079        Sunshine Surfer Van
# 4    42057      Ultralight Helicopter
#
#                                            prod_desc      theme_name  \
# 0  Fly in the exploration gear and fly out the cr...            City
# 1  Explore the Land of Ooo with Jake and Lumpy Sp...     DIMENSIONS™
# 2  Learn about daily routines with this easy-to-b...          DUPLO®
# 3  Enjoy seaside fun with the 3-in-1 Sunshine Sur...  Creator 3-in-1
# 4  Take to the skies with the Ultralight Helicopter!         Technic
#
#    piece_count  min_age  max_age  difficulty_level  num_reviews  star_rating  \
# 0          330      7.0     12.0                 1          3.0          4.3
# 1           96      7.0     14.0                 1          3.0          4.7
# 2           25      1.5      5.0                 1          3.0          5.0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   prod_id           558 non-null    int64
#  1   set_name          558 non-null    object
#  2   prod_desc         544 non-null    object
#  3   theme_name        558 non-null    object
#  4   piece_count       558 non-null    int64
#  5   min_age           558 non-null    float64
#  6   max_age           558 non-null    float64
#  7   difficulty_level  558 non-null    int64
#  8   num_reviews       490 non-null    float64
#  9   star_rating       490 non-null    float64
#  10  list_price        558 non-null    float64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 48.1+ KB

# %%
train.shape
# Out:
# (558, 11)

# %%
train.tail()
# Out:
#      prod_id                       set_name  \
# 553    71343  The Powerpuff Girls™ Fun Pack
# 554    75114      First Order Stormtrooper™
# 555    41597                    Go Brick Me
# 556    75116                           Finn
# 557    76097      Lex Luthor™ Mech Takedown
#
#                                              prod_desc  \
# 553  Save the world before bedtime in the LEGO® DIM...
# 554         Prepare for battle against the Resistance!
# 555      Build a LEGO® BrickHeadz version of yourself!
# 556            Practice your warrior skills with Finn!
# 557  Power up for battle against the Lex Luthor™ Mech!
#
#                   theme_name  piece_count  min_age  max_age  difficulty_level  \
# 553              DIMENSIONS™           56      7.0     14.0                 1
# 554               Star Wars™           81      7.0     14.0                 0
# 555               BrickHeadz          708     10.0     99.0                 2
# ...

# %%
train.isnull()
# Out:
#      prod_id  set_name  prod_desc  theme_name  piece_count  min_age  max_age  \
# 0      False     False      False       False        False    False    False
# 1      False     False      False       False        False    False    False
# 2      False     False      False       False        False    False    False
# 3      False     False      False       False        False    False    False
# 4      False     False      False       False        False    False    False
# ..       ...       ...        ...         ...          ...      ...      ...
# 553    False     False      False       False        False    False    False
# 554    False     False      False       False        False    False    False
# 555    False     False      False       False        False    False    False
# 556    False     False      False       False        False    False    False
# 557    False     False      False       False        False    False    False
#
# ...

# %%
train.isnull().sum()
# Out:
# prod_id              0
# set_name             0
# prod_desc           14
# theme_name           0
# piece_count          0
# min_age              0
# max_age              0
# difficulty_level     0
# num_reviews         68
# star_rating         68
# list_price           0
# dtype: int64

# %%
train.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 553    False
# 554    False
# 555    False
# 556    False
# 557    False
# Length: 558, dtype: bool

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.set_name.value_counts()
# Out:
# Rey                          2
# Captain Phasma™              2
# Chewbacca™                   2
# Darth Vader™                 2
# Puppy Pampering              1
#                             ..
# Police Starter Set           1
# Creative Suitcase            1
# U-Wing™ Microfighter         1
# New York City                1
# Lex Luthor™ Mech Takedown    1
# Name: set_name, Length: 554, dtype: int64

# %%
train.set_name.value_counts().plot(kind='bar')
plt.title('Lego Pricing Prediction')
plt.xlabel('LEGO Name')
plt.ylabel('Counts')
plt.show()

# %%
train.theme_name.value_counts()
# Out:
# Star Wars™                               73
# DUPLO®                                   56
# City                                     53
# Friends                                  30
# Technic                                  28
# Creator 3-in-1                           26
# Juniors                                  26
# BrickHeadz                               24
# NEXO KNIGHTS™                            22
# DIMENSIONS™                              20
# Creator Expert                           16
# Disney™                                  16
# Marvel Super Heroes                      16
# THE LEGO® BATMAN MOVIE                   16
# Classic                                  15
# NINJAGO®                                 15
# Minecraft™                               14
# DC Comics™ Super Heroes                  14
# THE LEGO® NINJAGO® MOVIE™                12
# MINDSTORMS®                              11
# Elves                                    10
# ...

# %%
train.theme_name.value_counts().plot(kind = 'bar')
plt.title('Lego Pricing Prediction')
plt.xlabel('Theme Name')
plt.ylabel('Counts')
plt.show()

# %%
train.piece_count.value_counts()
# Out:
# 1      11
# 109     5
# 8       4
# 174     4
# 92      4
#        ..
# 254     1
# 391     1
# 416     1
# 378     1
# 406     1
# Name: piece_count, Length: 367, dtype: int64

# %%
train.star_rating.value_counts()
# Out:
# 5.0    124
# 4.8     52
# 4.5     48
# 4.0     44
# 4.7     42
# 4.6     35
# 4.3     27
# 4.4     24
# 4.9     20
# 4.1     15
# 4.2     12
# 3.8      9
# 3.4      5
# 3.7      5
# 3.6      5
# 3.5      4
# 3.2      4
# 3.9      3
# 3.0      3
# 3.3      3
# 2.6      3
# 2.8      2
# 2.9      1
# Name: star_rating, dtype: int64

# %%
train.star_rating.value_counts().plot(kind='bar')
plt.title('Lego Pricing Prediction')
plt.xlabel('Star Rating')
plt.ylabel('Counts')
plt.show()

# %%
train.list_price.value_counts()
# Out:
# 19.9900     86
# 29.9900     76
# 9.9900      75
# 14.9900     38
# 39.9900     35
# 24.9900     30
# 49.9900     24
# 59.9900     24
# 99.9900     16
# 79.9900     16
# 69.9900     14
# 4.9900      12
# 119.9900     7
# 199.9900     6
# 159.9900     6
# 89.9900      6
# 12.9900      6
# 34.9900      5
# 31.9900      4
# 3.9900       4
# 129.9900     4
# 149.9900     4
# 44.9900      4
# 6.9900       3
# 139.9900     3
# 30.3924      3
# 349.9900     3
# 109.9900     3
# 169.9900     3
# 16.9900      3
# 18.9620      2
# 30.3620      2
# 21.9900      2
# 179.9900     2
# 11.9900      2
# 45.5924      2
# 279.9900     2
# 91.1924      1
# 18.2878      1
# 299.9900     1
# 754.9900     1
# 239.9900     1
# 7.9900       1
# 2.4900       1
# 249.9900     1
# 369.9900     1
# 36.9900      1
# 799.9900     1
# 84.9900      1
# 26.9900      1
# 5.9900       1
# 83.5924      1
# 54.9900      1
# 15.9900      1
# 269.9900     1
# 88.9900      1
# 499.9900     1
# 227.9924     1
# ...

# %%
train.list_price.value_counts().plot(kind = 'bar')
plt.title('Lego Pricing Prediction')
plt.xlabel('List Price')
plt.ylabel('Counts')
plt.show()

# %%
#Load Test Dataset
test = pd.read_csv('lego_test.csv')

# %%
test
# Out:
#      prod_id                         set_name  \
# 0      10744      Thunder Hollow Crazy 8 Race
# 1      70358          Aaron's Stone Destroyer
# 2      42060                    Roadwork Crew
# 3      75877                 Mercedes-AMG GT3
# 4      76101         Outrider Dropship Attack
# ..       ...                              ...
# 181    70921  Harley Quinn™ Cannonball Attack
# 182    41601                          Cyborg™
# 183    60108               Fire Response Unit
# 184    10736  Anna & Elsa's Frozen Playground
# 185    41147            Anna's Snow Adventure
#
#                                              prod_desc  \
# 0    Roll up for a demolition derby at the Disney•P...
# 1      Protect Robot Hoodlum from The Bedrock Monster!
# 2                           Call in the Roadwork Crew!
# 3               Customize the awesome AMG GT3 to race!
# 4        Defend Wakanda from attack with the Avengers!
# ..                                                 ...
# ...

# %%
test.head()
# Out:
#    prod_id                     set_name  \
# 0    10744  Thunder Hollow Crazy 8 Race
# 1    70358      Aaron's Stone Destroyer
# 2    42060                Roadwork Crew
# 3    75877             Mercedes-AMG GT3
# 4    76101     Outrider Dropship Attack
#
#                                            prod_desc           theme_name  \
# 0  Roll up for a demolition derby at the Disney•P...              Juniors
# 1    Protect Robot Hoodlum from The Bedrock Monster!        NEXO KNIGHTS™
# 2                         Call in the Roadwork Crew!              Technic
# 3             Customize the awesome AMG GT3 to race!      Speed Champions
# 4      Defend Wakanda from attack with the Avengers!  Marvel Super Heroes
#
#    piece_count  min_age  max_age  difficulty_level  num_reviews  star_rating  \
# 0          191      4.0      7.0                 2          2.0          5.0
# 1          251      8.0     14.0                 2          1.0          5.0
# ...

# %%
test.tail()
# Out:
#      prod_id                         set_name  \
# 181    70921  Harley Quinn™ Cannonball Attack
# 182    41601                          Cyborg™
# 183    60108               Fire Response Unit
# 184    10736  Anna & Elsa's Frozen Playground
# 185    41147            Anna's Snow Adventure
#
#                                              prod_desc  \
# 181           Dodge Harley Quinn’s cannonball attacks!
# 182       Get an upgrade with LEGO® BrickHeadz Cyborg™
# 183              Call the Fire Response Unit for help!
# 184  Play in the snow with Anna and Elsa at the ice...
# 185  Take a break with Anna and her horse on their ...
#
#                  theme_name  piece_count  min_age  max_age  difficulty_level  \
# 181  THE LEGO® BATMAN MOVIE          425      7.0     14.0                 2
# 182              BrickHeadz          108     10.0     99.0                 1
# 183                    City          257      5.0     12.0                 2
# ...

# %%
test.shape
# Out:
# (186, 11)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   prod_id           186 non-null    int64
#  1   set_name          186 non-null    object
#  2   prod_desc         180 non-null    object
#  3   theme_name        186 non-null    object
#  4   piece_count       186 non-null    int64
#  5   min_age           186 non-null    float64
#  6   max_age           186 non-null    float64
#  7   difficulty_level  186 non-null    int64
#  8   num_reviews       165 non-null    float64
#  9   star_rating       165 non-null    float64
#  10  list_price        186 non-null    float64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 16.1+ KB

# %%
test.isnull().sum()
# Out:
# prod_id              0
# set_name             0
# prod_desc            6
# theme_name           0
# piece_count          0
# min_age              0
# max_age              0
# difficulty_level     0
# num_reviews         21
# star_rating         21
# list_price           0
# dtype: int64

# %%
test.duplicated().sum()
# Out:
# 0

# %%
test.dtypes
# Out:
# prod_id               int64
# set_name             object
# prod_desc            object
# theme_name           object
# piece_count           int64
# min_age             float64
# max_age             float64
# difficulty_level      int64
# num_reviews         float64
# star_rating         float64
# list_price          float64
# dtype: object

# %%
#Import Further Libraries
import numpy as np
import seaborn as sns

# %%
#X and y for train dataset
X_train = train.drop('list_price', axis = 1)
y_train = train['list_price']

# %%
#EDA of X_train
X_train
# Out:
#      prod_id                       set_name  \
# 0      60123      Volcano Supply Helicopter
# 1      71246      Adventure Time™ Team Pack
# 2      10616             My First Playhouse
# 3      31079            Sunshine Surfer Van
# 4      42057          Ultralight Helicopter
# ..       ...                            ...
# 553    71343  The Powerpuff Girls™ Fun Pack
# 554    75114      First Order Stormtrooper™
# 555    41597                    Go Brick Me
# 556    75116                           Finn
# 557    76097      Lex Luthor™ Mech Takedown
#
#                                              prod_desc  \
# 0    Fly in the exploration gear and fly out the cr...
# 1    Explore the Land of Ooo with Jake and Lumpy Sp...
# 2    Learn about daily routines with this easy-to-b...
# 3    Enjoy seaside fun with the 3-in-1 Sunshine Sur...
# 4    Take to the skies with the Ultralight Helicopter!
# ..                                                 ...
# ...

# %%
X_train.head()
# Out:
#    prod_id                   set_name  \
# 0    60123  Volcano Supply Helicopter
# 1    71246  Adventure Time™ Team Pack
# 2    10616         My First Playhouse
# 3    31079        Sunshine Surfer Van
# 4    42057      Ultralight Helicopter
#
#                                            prod_desc      theme_name  \
# 0  Fly in the exploration gear and fly out the cr...            City
# 1  Explore the Land of Ooo with Jake and Lumpy Sp...     DIMENSIONS™
# 2  Learn about daily routines with this easy-to-b...          DUPLO®
# 3  Enjoy seaside fun with the 3-in-1 Sunshine Sur...  Creator 3-in-1
# 4  Take to the skies with the Ultralight Helicopter!         Technic
#
#    piece_count  min_age  max_age  difficulty_level  num_reviews  star_rating
# 0          330      7.0     12.0                 1          3.0          4.3
# 1           96      7.0     14.0                 1          3.0          4.7
# 2           25      1.5      5.0                 1          3.0          5.0
# ...

# %%
X_train.tail()
# Out:
#      prod_id                       set_name  \
# 553    71343  The Powerpuff Girls™ Fun Pack
# 554    75114      First Order Stormtrooper™
# 555    41597                    Go Brick Me
# 556    75116                           Finn
# 557    76097      Lex Luthor™ Mech Takedown
#
#                                              prod_desc  \
# 553  Save the world before bedtime in the LEGO® DIM...
# 554         Prepare for battle against the Resistance!
# 555      Build a LEGO® BrickHeadz version of yourself!
# 556            Practice your warrior skills with Finn!
# 557  Power up for battle against the Lex Luthor™ Mech!
#
#                   theme_name  piece_count  min_age  max_age  difficulty_level  \
# 553              DIMENSIONS™           56      7.0     14.0                 1
# 554               Star Wars™           81      7.0     14.0                 0
# 555               BrickHeadz          708     10.0     99.0                 2
# ...

# %%
X_train.shape
# Out:
# (558, 10)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   prod_id           558 non-null    int64
#  1   set_name          558 non-null    object
#  2   prod_desc         544 non-null    object
#  3   theme_name        558 non-null    object
#  4   piece_count       558 non-null    int64
#  5   min_age           558 non-null    float64
#  6   max_age           558 non-null    float64
#  7   difficulty_level  558 non-null    int64
#  8   num_reviews       490 non-null    float64
#  9   star_rating       490 non-null    float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 43.7+ KB

# %%
X_train.isnull().sum()
# Out:
# prod_id              0
# set_name             0
# prod_desc           14
# theme_name           0
# piece_count          0
# min_age              0
# max_age              0
# difficulty_level     0
# num_reviews         68
# star_rating         68
# dtype: int64

# %%
X_train.duplicated().sum()
# Out:
# 0

# %%
#EDA of y_train
y_train
# Out:
# 0      49.990
# 1      30.362
# 2      19.990
# 3      34.990
# 4      19.990
#         ...
# 553    14.990
# 554    19.990
# 555    29.990
# 556    24.990
# 557    39.990
# Name: list_price, Length: 558, dtype: float64

# %%
y_train.shape
# Out:
# (558,)

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 558 entries, 0 to 557
# Series name: list_price
# Non-Null Count  Dtype
# --------------  -----
# 558 non-null    float64
# dtypes: float64(1)
# memory usage: 4.5 KB

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
y_train.duplicated().sum()
# Out:
# 500

# %%
#X and y of test dataset
X_test = test.drop('list_price', axis=1)
y_test = test['list_price']

# %%
#EDA of X_test
X_test
# Out:
#      prod_id                         set_name  \
# 0      10744      Thunder Hollow Crazy 8 Race
# 1      70358          Aaron's Stone Destroyer
# 2      42060                    Roadwork Crew
# 3      75877                 Mercedes-AMG GT3
# 4      76101         Outrider Dropship Attack
# ..       ...                              ...
# 181    70921  Harley Quinn™ Cannonball Attack
# 182    41601                          Cyborg™
# 183    60108               Fire Response Unit
# 184    10736  Anna & Elsa's Frozen Playground
# 185    41147            Anna's Snow Adventure
#
#                                              prod_desc  \
# 0    Roll up for a demolition derby at the Disney•P...
# 1      Protect Robot Hoodlum from The Bedrock Monster!
# 2                           Call in the Roadwork Crew!
# 3               Customize the awesome AMG GT3 to race!
# 4        Defend Wakanda from attack with the Avengers!
# ..                                                 ...
# ...

# %%
X_test.head()
# Out:
#    prod_id                     set_name  \
# 0    10744  Thunder Hollow Crazy 8 Race
# 1    70358      Aaron's Stone Destroyer
# 2    42060                Roadwork Crew
# 3    75877             Mercedes-AMG GT3
# 4    76101     Outrider Dropship Attack
#
#                                            prod_desc           theme_name  \
# 0  Roll up for a demolition derby at the Disney•P...              Juniors
# 1    Protect Robot Hoodlum from The Bedrock Monster!        NEXO KNIGHTS™
# 2                         Call in the Roadwork Crew!              Technic
# 3             Customize the awesome AMG GT3 to race!      Speed Champions
# 4      Defend Wakanda from attack with the Avengers!  Marvel Super Heroes
#
#    piece_count  min_age  max_age  difficulty_level  num_reviews  star_rating
# 0          191      4.0      7.0                 2          2.0          5.0
# 1          251      8.0     14.0                 2          1.0          5.0
# ...

# %%
X_test.tail()
# Out:
#      prod_id                         set_name  \
# 181    70921  Harley Quinn™ Cannonball Attack
# 182    41601                          Cyborg™
# 183    60108               Fire Response Unit
# 184    10736  Anna & Elsa's Frozen Playground
# 185    41147            Anna's Snow Adventure
#
#                                              prod_desc  \
# 181           Dodge Harley Quinn’s cannonball attacks!
# 182       Get an upgrade with LEGO® BrickHeadz Cyborg™
# 183              Call the Fire Response Unit for help!
# 184  Play in the snow with Anna and Elsa at the ice...
# 185  Take a break with Anna and her horse on their ...
#
#                  theme_name  piece_count  min_age  max_age  difficulty_level  \
# 181  THE LEGO® BATMAN MOVIE          425      7.0     14.0                 2
# 182              BrickHeadz          108     10.0     99.0                 1
# 183                    City          257      5.0     12.0                 2
# ...

# %%
X_test.shape
# Out:
# (186, 10)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   prod_id           186 non-null    int64
#  1   set_name          186 non-null    object
#  2   prod_desc         180 non-null    object
#  3   theme_name        186 non-null    object
#  4   piece_count       186 non-null    int64
#  5   min_age           186 non-null    float64
#  6   max_age           186 non-null    float64
#  7   difficulty_level  186 non-null    int64
#  8   num_reviews       165 non-null    float64
#  9   star_rating       165 non-null    float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 14.7+ KB

# %%
X_test.isnull().sum()
# Out:
# prod_id              0
# set_name             0
# prod_desc            6
# theme_name           0
# piece_count          0
# min_age              0
# max_age              0
# difficulty_level     0
# num_reviews         21
# star_rating         21
# dtype: int64

# %%
X_test.duplicated().sum()
# Out:
# 0

# %%
X_test.star_rating.value_counts()
# Out:
# 5.0    35
# 4.6    19
# 4.7    19
# 4.0    16
# 4.8    14
# 4.3    12
# 4.5    10
# 4.1     5
# 4.9     5
# 3.5     5
# 4.4     4
# 3.9     4
# 3.7     4
# 3.8     3
# 4.2     2
# 2.2     1
# 2.7     1
# 2.6     1
# 1.8     1
# 3.6     1
# 3.0     1
# 2.5     1
# 3.2     1
# Name: star_rating, dtype: int64

# %%
#EDA of y_test
y_test
# Out:
# 0      34.99
# 1      24.99
# 2      29.99
# 3      14.99
# 4      14.99
#        ...
# 181    49.99
# 182     9.99
# 183    39.99
# 184    24.99
# 185    19.99
# Name: list_price, Length: 186, dtype: float64

# %%
y_test.head()
# Out:
# 0    34.99
# 1    24.99
# 2    29.99
# 3    14.99
# 4    14.99
# Name: list_price, dtype: float64

# %%
y_test.tail()
# Out:
# 181    49.99
# 182     9.99
# 183    39.99
# 184    24.99
# 185    19.99
# Name: list_price, dtype: float64

# %%
y_test.shape
# Out:
# (186,)

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 186 entries, 0 to 185
# Series name: list_price
# Non-Null Count  Dtype
# --------------  -----
# 186 non-null    float64
# dtypes: float64(1)
# memory usage: 1.6 KB

# %%
y_test.isnull().sum()
# Out:
# 0

# %%
y_test.duplicated().sum()
# Out:
# 149
