# %%
#import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\hp\\Python_Tutorial'

# %%
#Import Dataset
df = pd.read_csv('loan.csv')
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14588\4089370516.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan.csv')
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# ...

# %%
#Explore Dataset
df.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# ...

# %%
df.tail()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39712  92187      92174       2500         2500           1075.0   36 months
# 39713  90665      90607       8500         8500            875.0   36 months
# 39714  90395      90390       5000         5000           1325.0   36 months
# 39715  90376      89243       5000         5000            650.0   36 months
# 39716  87023      86999       7500         7500            800.0   36 months
#
#       int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 39712    8.07%        78.42     A        A4  ...                NaN
# 39713   10.28%       275.38     C        C1  ...                NaN
# 39714    8.07%       156.84     A        A4  ...                NaN
# 39715    7.43%       155.38     A        A2  ...                NaN
# 39716   13.75%       255.43     E        E2  ...                NaN
#
#       num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# ...

# %%
df.tail(10)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39707  92666      92661       5000         5000            525.0   36 months
# 39708  92552      92542       5000         5000            375.0   36 months
# 39709  92533      92529       5000         5000            675.0   36 months
# 39710  92507      92502       5000         5000            250.0   36 months
# 39711  92402      92390       5000         5000            700.0   36 months
# 39712  92187      92174       2500         2500           1075.0   36 months
# 39713  90665      90607       8500         8500            875.0   36 months
# 39714  90395      90390       5000         5000           1325.0   36 months
# 39715  90376      89243       5000         5000            650.0   36 months
# 39716  87023      86999       7500         7500            800.0   36 months
#
#       int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# ...

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.dtypes
# Out:
# id                              int64
# member_id                       int64
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
#                                ...
# tax_liens                     float64
# tot_hi_cred_lim               float64
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# Length: 111, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df.isnull()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 0      False      False      False        False            False  False
# 1      False      False      False        False            False  False
# 2      False      False      False        False            False  False
# 3      False      False      False        False            False  False
# 4      False      False      False        False            False  False
# ...      ...        ...        ...          ...              ...    ...
# 39712  False      False      False        False            False  False
# 39713  False      False      False        False            False  False
# 39714  False      False      False        False            False  False
# 39715  False      False      False        False            False  False
# 39716  False      False      False        False            False  False
#
#        int_rate  installment  grade  sub_grade  ...  num_tl_90g_dpd_24m  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
df.tail(0-39500)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39500  178157     177995      14400        14400       124.994746   36 months
# 39501  177913     171100      15000         7000       350.000000   36 months
# 39502  177259     154006      17950        17950       425.000000   36 months
# 39503  177075     177072      15000        15000      1999.130000   36 months
# 39504  176995     176989      25000        25000       675.006307   36 months
# ...       ...        ...        ...          ...              ...         ...
# 39712   92187      92174       2500         2500      1075.000000   36 months
# 39713   90665      90607       8500         8500       875.000000   36 months
# 39714   90395      90390       5000         5000      1325.000000   36 months
# 39715   90376      89243       5000         5000       650.000000   36 months
# 39716   87023      86999       7500         7500       800.000000   36 months
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.id.value_counts()
# Out:
# 1077501    1
# 568534     1
# 568659     1
# 567165     1
# 568531     1
#           ..
# 785667     1
# 785659     1
# 785630     1
# 785626     1
# 87023      1
# Name: id, Length: 39717, dtype: int64

# %%
df.grade.value_counts()
# Out:
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: grade, dtype: int64

# %%
df.loan_amnt.value_counts()
# Out:
# 10000    2833
# 12000    2334
# 5000     2051
# 6000     1908
# 15000    1895
#          ...
# 22875       1
# 8175        1
# 19475       1
# 21225       1
# 22550       1
# Name: loan_amnt, Length: 885, dtype: int64

# %%
df.term.value_counts()
# Out:
#  36 months    29096
#  60 months    10621
# Name: term, dtype: int64

# %%
df.int_rate.value_counts()
# Out:
# 10.99%    956
# 13.49%    826
# 11.49%    825
# 7.51%     787
# 7.88%     725
#          ...
# 18.36%      1
# 16.96%      1
# 16.15%      1
# 16.01%      1
# 17.44%      1
# Name: int_rate, Length: 371, dtype: int64

# %%
df.installment.value_counts()
# Out:
# 311.11     68
# 180.96     59
# 311.02     54
# 150.80     48
# 368.45     46
#            ..
# 1224.46     1
# 63.44       1
# 157.67      1
# 492.34      1
# 255.43      1
# Name: installment, Length: 15383, dtype: int64

# %%
#Grade Bar Chart
df.grade.value_counts().plot(kind='bar')
plt.title("Grading of the load applicants")
plt.xlabel("Grades")
plt.xticks(rotation=30)
plt.ylabel("Counts based on Grades")
plt.yticks(rotation=30)
plt.show()

# %%
#Interest Rate Bar Chart
df.int_rate.value_counts().plot(kind='bar')
plt.title("Interest Rate of Loan")
plt.xlabel("Interest Rate")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.yticks(rotation=45)
plt.show()

# %%
#Load Datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\hp\\Python_Tutorial'

# %%
#import datasets
df = pd.read_csv('loan.csv')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14844\190404948.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan.csv')

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# ...

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df.tail()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39712  92187      92174       2500         2500           1075.0   36 months
# 39713  90665      90607       8500         8500            875.0   36 months
# 39714  90395      90390       5000         5000           1325.0   36 months
# 39715  90376      89243       5000         5000            650.0   36 months
# 39716  87023      86999       7500         7500            800.0   36 months
#
#       int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 39712    8.07%        78.42     A        A4  ...                NaN
# 39713   10.28%       275.38     C        C1  ...                NaN
# 39714    8.07%       156.84     A        A4  ...                NaN
# 39715    7.43%       155.38     A        A2  ...                NaN
# 39716   13.75%       255.43     E        E2  ...                NaN
#
#       num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# ...

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.dtypes
# Out:
# id                              int64
# member_id                       int64
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
#                                ...
# tax_liens                     float64
# tot_hi_cred_lim               float64
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# Length: 111, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df.isnull()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 0      False      False      False        False            False  False
# 1      False      False      False        False            False  False
# 2      False      False      False        False            False  False
# 3      False      False      False        False            False  False
# 4      False      False      False        False            False  False
# ...      ...        ...        ...          ...              ...    ...
# 39712  False      False      False        False            False  False
# 39713  False      False      False        False            False  False
# 39714  False      False      False        False            False  False
# 39715  False      False      False        False            False  False
# 39716  False      False      False        False            False  False
#
#        int_rate  installment  grade  sub_grade  ...  num_tl_90g_dpd_24m  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39712    False
# 39713    False
# 39714    False
# 39715    False
# 39716    False
# Length: 39717, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.id.value_counts()
# Out:
# 1077501    1
# 568534     1
# 568659     1
# 567165     1
# 568531     1
#           ..
# 785667     1
# 785659     1
# 785630     1
# 785626     1
# 87023      1
# Name: id, Length: 39717, dtype: int64

# %%
df.grade.value_counts()
# Out:
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: grade, dtype: int64

# %%
df.loan_amnt.value_counts()
# Out:
# 10000    2833
# 12000    2334
# 5000     2051
# 6000     1908
# 15000    1895
#          ...
# 22875       1
# 8175        1
# 19475       1
# 21225       1
# 22550       1
# Name: loan_amnt, Length: 885, dtype: int64

# %%
df.term.value_counts()
# Out:
#  36 months    29096
#  60 months    10621
# Name: term, dtype: int64

# %%
df.int_rate.value_counts()
# Out:
# 10.99%    956
# 13.49%    826
# 11.49%    825
# 7.51%     787
# 7.88%     725
#          ...
# 18.36%      1
# 16.96%      1
# 16.15%      1
# 16.01%      1
# 17.44%      1
# Name: int_rate, Length: 371, dtype: int64

# %%
df.installment.value_counts()
# Out:
# 311.11     68
# 180.96     59
# 311.02     54
# 150.80     48
# 368.45     46
#            ..
# 1224.46     1
# 63.44       1
# 157.67      1
# 492.34      1
# 255.43      1
# Name: installment, Length: 15383, dtype: int64

# %%
df.grade.value_counts()
# Out:
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: grade, dtype: int64

# %%
df.grade.value_counts().plot(kind='bar')
plt.title('Grading of the Loan Applicants')
plt.xlabel('Grade')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
df.grade.value_counts().plot(kind='pie')
plt.title('Grading of the Loan Applicants')
plt.show()

# %%
df.int_rate.value_counts()
# Out:
# 10.99%    956
# 13.49%    826
# 11.49%    825
# 7.51%     787
# 7.88%     725
#          ...
# 18.36%      1
# 16.96%      1
# 16.15%      1
# 16.01%      1
# 17.44%      1
# Name: int_rate, Length: 371, dtype: int64

# %%
df.int_rate.value_counts().plot(kind='bar')
plt.title('Interest Rates of Various Loans')
plt.xlabel('Interest Rate')
plt.ylabel('Counts')
plt.xticks(rotation=30)
plt.yticks(rotation=30)
plt.show()

# %%
df.int_rate.value_counts().plot(kind='pie')
plt.title('Interest Rate of Various Loans')
plt.show()
